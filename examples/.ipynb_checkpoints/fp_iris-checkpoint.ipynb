# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from sklearn.preprocessing import StandardScaler

# %%
from pyriad.agents import FPAgent
from pyriad.swarms import FPSwarm

# %%
df = pd.read_csv('../data/iris.csv')
df = df.drop(columns=['Id'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.pairplot(data=df,hue="Species",palette="Set2")
plt.show()

# %%
df = df.drop(columns=['Species'])

# %%
scaler = StandardScaler()

values = df['SepalLengthCm'].values
values = values.reshape((len(values), 1))
scaler = scaler.fit(values)
df['SepalLengthCm'] = scaler.transform(values)

values = df['SepalWidthCm'].values
values = values.reshape((len(values), 1))
scaler = scaler.fit(values)
df['SepalWidthCm'] = scaler.transform(values)

values = df['PetalLengthCm'].values
values = values.reshape((len(values), 1))
scaler = scaler.fit(values)
df['PetalLengthCm'] = scaler.transform(values)

values = df['PetalWidthCm'].values
values = values.reshape((len(values), 1))
scaler = scaler.fit(values)
df['PetalWidthCm'] = scaler.transform(values)

# %%
agent = FPAgent(n_clusters=3, levy_alpha=2, switch_probability=0.6)
swarm = FPSwarm()
swarm.populate(agent, 19)

# %%
tensor_data = torch.tensor(df.values).float()

# %%
swarm.train(tensor_data, 500)
# Out:
# Episode 20	Average Score: 626.28
# Episode 40	Average Score: 415.99
# Episode 60	Average Score: 353.83
# Episode 80	Average Score: 199.42
# Episode 100	Average Score: 158.40
# Episode 120	Average Score: 164.16
# Episode 140	Average Score: 153.04
# Episode 160	Average Score: 159.86
# Episode 180	Average Score: 144.31
# Episode 200	Average Score: 143.86
# Episode 220	Average Score: 142.53
# Episode 240	Average Score: 141.99
# Episode 260	Average Score: 141.70
# Episode 280	Average Score: 141.85
# Episode 300	Average Score: 143.63
# Episode 320	Average Score: 142.40
# Episode 340	Average Score: 141.65
# Episode 360	Average Score: 141.47
# Episode 380	Average Score: 141.42
# Episode 400	Average Score: 141.40
# Episode 420	Average Score: 141.38
# Episode 440	Average Score: 141.37
# Episode 460	Average Score: 141.36
# Episode 480	Average Score: 141.35
# Episode 500	Average Score: 141.34

# %%
labels, score = swarm.predict(tensor_data)
print(score)
# Out:
# tensor(141.3455)

# %%
labels = labels.numpy().astype(str)
for i in range(len(labels)):
    labels[i] += 'c'
df['predicted_species'] = labels
sns.pairplot(data=df,hue="predicted_species",palette="Set2")
plt.show()
