# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from sklearn.preprocessing import StandardScaler

# %%
from pyriad.agents import GWOAgent
from pyriad.swarms import GWOSwarm

# %%
df = pd.read_csv('../data/iris.csv')
df = df.drop(columns=['Id'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.pairplot(data=df,hue="Species",palette="Set2")
plt.show()

# %%
df = df.drop(columns=['Species'])

# %%
scaler = StandardScaler()

values = df['SepalLengthCm'].values
values = values.reshape((len(values), 1))
scaler = scaler.fit(values)
df['SepalLengthCm'] = scaler.transform(values)

values = df['SepalWidthCm'].values
values = values.reshape((len(values), 1))
scaler = scaler.fit(values)
df['SepalWidthCm'] = scaler.transform(values)

values = df['PetalLengthCm'].values
values = values.reshape((len(values), 1))
scaler = scaler.fit(values)
df['PetalLengthCm'] = scaler.transform(values)

values = df['PetalWidthCm'].values
values = values.reshape((len(values), 1))
scaler = scaler.fit(values)
df['PetalWidthCm'] = scaler.transform(values)

# %%
agent = GWOAgent(n_clusters=3)
swarm = GWOSwarm()
swarm.populate(agent, 29)

# %%
tensor_data = torch.tensor(df.values).float()

# %%
swarm.train(tensor_data, 500)
# Out:
# Episode 20	Average Score: 356.36
# Episode 40	Average Score: 248.13
# Episode 60	Average Score: 233.87
# Episode 80	Average Score: 217.82
# Episode 100	Average Score: 211.03
# Episode 120	Average Score: 195.56
# Episode 140	Average Score: 187.93
# Episode 160	Average Score: 185.01
# Episode 180	Average Score: 175.15
# Episode 200	Average Score: 173.23
# Episode 220	Average Score: 166.81
# Episode 240	Average Score: 161.82
# Episode 260	Average Score: 160.20
# Episode 280	Average Score: 157.00
# Episode 300	Average Score: 153.97
# Episode 320	Average Score: 151.42
# Episode 340	Average Score: 148.95
# Episode 360	Average Score: 147.30
# Episode 380	Average Score: 145.63
# Episode 400	Average Score: 144.76
# Episode 420	Average Score: 143.49
# Episode 440	Average Score: 142.60
# Episode 460	Average Score: 142.04
# Episode 480	Average Score: 141.63
# Episode 500	Average Score: 141.45

# %%
labels, score = swarm.predict(tensor_data)
print(score)
# Out:
# tensor(141.4358)

# %%
labels = labels.numpy().astype(str)
for i in range(len(labels)):
    labels[i] += 'c'
df['predicted_species'] = labels
sns.pairplot(data=df,hue="predicted_species",palette="Set2")
plt.show()
