# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from sklearn.preprocessing import StandardScaler

# %%
from pyriad.agents import CSAgent
from pyriad.swarms import CSSwarm

# %%
df = pd.read_csv('../data/iris.csv')
df = df.drop(columns=['Id'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.pairplot(data=df,hue="Species",palette="Set2")
plt.show()

# %%
df = df.drop(columns=['Species'])

# %%
scaler = StandardScaler()

values = df['SepalLengthCm'].values
values = values.reshape((len(values), 1))
scaler = scaler.fit(values)
df['SepalLengthCm'] = scaler.transform(values)

values = df['SepalWidthCm'].values
values = values.reshape((len(values), 1))
scaler = scaler.fit(values)
df['SepalWidthCm'] = scaler.transform(values)

values = df['PetalLengthCm'].values
values = values.reshape((len(values), 1))
scaler = scaler.fit(values)
df['PetalLengthCm'] = scaler.transform(values)

values = df['PetalWidthCm'].values
values = values.reshape((len(values), 1))
scaler = scaler.fit(values)
df['PetalWidthCm'] = scaler.transform(values)

# %%
agent = CSAgent(n_clusters=3, levy_alpha=10)
swarm = CSSwarm(expose=0.7, discoverability=0.5)
swarm.populate(agent, 19)

# %%
tensor_data = torch.tensor(df.values).float()

# %%
swarm.train(tensor_data, 300)
# Out:
# Episode 20	Average Score: 238.24
# Episode 40	Average Score: 158.75
# Episode 60	Average Score: 145.52
# Episode 80	Average Score: 142.66
# Episode 100	Average Score: 142.09
# Episode 120	Average Score: 141.88
# Episode 140	Average Score: 141.69
# Episode 160	Average Score: 141.61
# Episode 180	Average Score: 141.50
# Episode 200	Average Score: 141.46
# Episode 220	Average Score: 141.50
# Episode 240	Average Score: 141.48
# Episode 260	Average Score: 141.44
# Episode 280	Average Score: 141.44
# Episode 300	Average Score: 141.44

# %%
labels, score = swarm.predict(tensor_data)
print(score)
# Out:
# tensor(141.4367)

# %%
labels = labels.numpy().astype(str)
for i in range(len(labels)):
    labels[i] += 'c'
df['predicted_species'] = labels
sns.pairplot(data=df,hue="predicted_species",palette="Set2")
plt.show()
